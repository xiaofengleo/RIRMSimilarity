# %%
#这个只需要在源代码中加入一个语句即可
import sys
import jieba
from os import path

#d = path.dirname(__file__)
stopwords_path = 'stopwords.txt' # 停用词词表

#jieba.add_word('路明非')
# 添加的自定义中文语句的代码在这里
# 添加的自定义中文语句的代码在这里
# 添加的自定义中文语句的代码在这里

text_path = 'envri-rmzh.txt' #设置要分析的文本路径
#text = open(path.join(d, text_path)).read()
text = open(text_path).read()


def jiebaclearText(text):
    mywordlist = []
    seg_list = jieba.cut(text, cut_all=False)
    liststr="/ ".join(seg_list)
    f_stop = open(stopwords_path)
    try:
        f_stop_text = f_stop.read( )
        f_stop_text=unicode(f_stop_text,'utf-8')
    finally:
        f_stop.close( )
    f_stop_seg_list=f_stop_text.split('\n')
    for myword in liststr.split('/'):
        if not(myword.strip() in f_stop_seg_list) and len(myword.strip())>1:
            mywordlist.append(myword)
    return ''.join(mywordlist)

text1 = jiebaclearText(text)
print(text1)
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /var/folders/8t/y4bqb2dj76z73s3251jjfk780000gp/T/jieba.cache
# Loading model cost 2.624 seconds.
# Prefix dict has been built succesfully.
# 环境 地球 科学研究 基础设施 本体 基于 环境 地球 科学研究 基础设施 参考模型 描述 环境 科学研究 基础设施 体系结构 信息流 本体 环境 科学研究 基础设施 环境 地球 科学研究 基础设施 本体 描述 环境 科学研究 基础设施 体系结构 信息流 本体 角色 调用 能力 提供 能力 参与 角色 创建 依照 属性 分类器 会员 一部分 调用 操作 涉及 映射 调用 操作 提供 操作 部分 扮演 角色 提供 操作 需求 资源 目标 定义 系统 目的 抽象 目标 服务 处理 用户 授权 请求 身份验证 然后 才能 继续执行 任何 特权 活动 服务 用于 请求 一个 正在 传输 数据 相关联 持久 标识符 获得 标识 采集 服务 负责 确保 根据 当前 政策 任何 数据 传送 基础设施 获取 服务 用于 请求 研究 基础设施 数据 整理 子系统 保存 数据 标注 标注 数据 概念 相关 数据 描述 含义 标注 数据 连接 概念 数据 描述 它们 含义 标注 数据 标注 服务 涉及 更新 记录 数据 目录 响应 用户 注释 请求 标注 服务 用于 获取 数据 采集 子系统 进行 任何 受限 交互 授权 认证 数据 对象 计算 对象 包含 获取 保存 发布 处理 研究 数据 派生 数据 产品 提供 系统 资源 对象 持久性 数据 副本 以便 数据 丢失 事件 用于 恢复 原始数据 备份 数据 代理 对象 充当 访问 存储 数据 存储 区内 数据 媒介 并且 便于 执行 语义 解释 查询 路由 代理 对象 研究 基础设施 导出 数据 需要 数据处理 子系统 检索 数据 传送 外部 资源 这个 过程 必须 数据 使用 数据 发布 子系统 处理 代理 数据 导出 采集 网络 以外 其他 来源 导入 数据 需要 数据 传送 数据 整理 子系统 之前 发布 子系统 进行 代理 代理 数据 导入 用于 原则上 基于 科学分析 输出 数据 仪器 校准 数据 读取 这个 借口 可以 用来 监视 给定 仪器 活动 校正 仪器 编目 服务 涉及 存储 基础 结构 数据 关联 数据 其他 特征 数据 编目 编目 服务 发布 解析 令牌 通过 标识符 链接 持久数据 对象 引用 组件 对象 提供 实际 系统 资源 对象 编程 访问 组件 对象 分配 计算 对象 通过 公共 提供 功能 计算 对象 功能 提供 某些 功能 计算能力 标识符 名称 事物 含义 定义 抽象 真实 东西 通过 句子 进行 人类 可读 定义 通过 其他 概念 机器 语句 关系 进行 机器 可读 定义 可以 用于 概念模型 最小 实体 可以 概念 平面 列表 一部分 概念 分层 列表 分层 词表 本体 概念 用于 配置 独立 仪器 数据 收集 以及 其他 配置 因子 配置 控制器 用于 协调 过程 控制器 提供 执行 资源 数据处理 任务 执行 协调 过程 协调 服务 委托 发送给 特定 执行 资源 所有 处理 任务 协调 阶段 工作 流程 启动 过程 执行 协同 服务 数据 采集 社区 行为 数据 获得 行为 提供 数据分析 功能 服务 数据分析 服务 提供数据 同化 功能 服务 数据 同化 服务 数据 代理 对象 充当 访问 存储 数据 存储 数据 中介 数据 代理 数据 审编 社区 行为 数据 审编 行为 数据 导出 管理 一个 多个 数据 存储 对象 外部 目标 例如 用户 机器 下游 服务 研究 基础设施 收集 数据 数据 移动 数据 导出 提供数据 提取 功能 服务 数据 抽取 服务 数据 导入 管理 外部 来源 例如 用户 发起 数据 来自 数据处理 派生 数据 一个 多个 数据 存储 对象 数据 移动 数据 导入 器为 数据挖掘 提供 功能 服务 数据挖掘 服务 数据处理 社区 行为 数据处理 行为 追溯 数据 来源 数据 记录 数据 生命周期 所有 状态 变化 及其 存储 之间 移动 数据 出处 数据 发布 社区 行为 数据 发布 服务 数据 暂存器 协调 管理 处理 子系统 之间 数据传输 数据 暂存器 研究 基础设施 进行 数据处理 需要 数据 整理 子系统 检索 数据 传送 数据处理 子系统 数据 暂存 数据 存储 控制器 提供 可能 拥有 内部 数据管理 机制 数据 存储 访问 数据 存储 控制器 一种 计算 操作 涉及 一个 计算 对象 一个 计算 对象 数据流 数据流 操作 数据传输 服务 涉及 数据 进出 基础设施 数据传输 服务 数据 传输器 用于 管理 研究 基础架构 一个 部分 一个 部分 数据 移动 数据 传送器 数据 使用 社区 行为 数据 使用 行为 连接 描述 这些 数据 数据 数据 数据 数据管理 数据 数据 存储 检索 逻辑 结构化 存储 存储系统 数据库 管理系统 用于 检索 存储 数据 整理 子系统 之外 外部 数据 存储 外部 数据 分发 数据 用于 采集 数据 采集 子系统 仪器 发送 原始数据 分发 原始数据 试验 实验室 用于 策划 数据 数据处理 设施 进行 交互 研究 人员 能够 部署 数据 进行 处理 计算 实验 获取 结果 试验 实验室 用于 检索 存储 数据 存储 子系统 数据 存储 区内 策划 数据 导出 审编 数据 用于 检索 任何 附加 数据 以便 正在 传输 数据 相关联 导出 数据 外部 资源 模拟 系统 范围 之外 资源 仍然 提供 输入 系统 接收 输出 外部 资源 野外 实验室 因为 现场 原始数据 相互作用 命名 用于 数据 采集 组件 进行 交互 研究 人员 能够 部署 校准 取消 部署 仪器 作为 集成 数据 采集 网络 一部分 收集 主要 原始 数据 基础设施 现场 实验室 能够 数据 采集 装置 实例 化新 仪器 控制器 野外 实验室 计算机系统 文件 方式 管理 数据 存储 检索 存储系统 文件 管理系统 数据 已经 最终 审查 因此 不会 改变 最终 评阅 数据 全局 概念模型 一个 概念 全局 概念 全局 概念模型 根据 预定 模式 数据 模式 添加 其他 数据 数据 注释 部分 重叠 增加 数据 执行 信息 对象 注释 标注 活动 含义 注解 数据 预定 本地 全局 概念模型 概念 在实践中 可以 通过 概念模型 概念 添加 标签 指针 完成 如果 概念 术语 例如 词表 作为 链接 数据 发布 数据 注释 意味着 输入 描述 数据 含义 术语 数据 语义 标注 之间 没有 确切 界限 标注 数据 一般 注解 行为 标注 实体 数据 意义 联系 起来 预定 本地 全球 概念模型 概念 可以 通过 添加 概念模型 概念 指向 数据 指针 完成 例如 如果 概念 同义词 术语 标识 作为 链接 数据 发布 注释 等同于 数据 术语 相关联 标注 数据 获取 一个 唯一 标识符 数据 关联 指定 标志符 建立 一个 相互 关联 概念 本地 全球 模型 可能 涉及 以下 问题 承诺 大量 科学家 数据 提供者 数据 使用者 应该 达成 协议 达成 一致 明确性 概念模型 明确 定义 可读性 模型 应该 人类 机器 本体 可读 例如 人类 机器 可读 同时 其他 概念 关系 表达 概念 含义 并且 近来 已经 越来越 重要 定义 添加 人类 可读 语言 可用性 概念模型 必须 长时间 参考 解除 引用 构建 概念模型 数据 复制到 其他 数据 存储 以便 发生 数据 丢失 事件 用于 恢复 原始数据 长期 保存 一种 特殊 类型 备份 开展 备份 验证 数据 质量 行动 例如 可能 涉及 消除 噪音 删除 明显 错误 数据 计算 校准 质量检查 可以 数据 生命周期 不同 阶段 进行 质量检查 可以 通过 软件工具 支持 那些 可以 自动 进行 流程 例如 统计 公差 检查 核实 质量 生成 持久数据 或元 数据 引用 引用 数据 转化 数据 描述 重用 一个 多个 服务 访问 接口 行为 描述 实现 算法 描述 服务 执行 一系列 数据 数据 请求 解释 结果 执行 一个 请求 通常 这个 顺序 有助于 加深 数据 了解 通常 这个 序列 可以 数据 数据 语义 标注 跟踪 数据 来源 可以 跟踪 数据处理 可以 通过 专门 软件 支持 这些 软件 可以 帮助 执行 数据 请求 结果 解释 顺序 挖掘 数据 检查 发布 数据 这些 数据 不会 更改 动作 触发 数据 状态 改变 最终 复查 在实践中 出于 溯源 目的 应该 记录 这种 状态 变化 注释 通常 存档 版本控制 操作 相结合 最终 评论 执行 转换规则 一个 单元 一个 单元 映射 概念 转换规则 含义 一个 概念模型 转换 一个 概念模型 例如 转换 代码 列表 执行 映射 测量 参数 观察 事件 测量 观察 性能 产生 测量 结果 执行 测量 观测 处理 数据 目的 转换 生成 数据 产品 计算 例如 统计 过程 模拟 模型 可视化 例如 字母 数字 图形 地理 数据处理 记录 起源 实例 处理 数据 提供 数据 创建 统计 模型 模拟 模型 摘要 生成 模型 数据 公开 获取 例如 可以 通过 万维网 上以 浏览 形式 呈现 它们 或者 通过 诸如 服务 服务 服务 服务 特征 服务 地图 服务 端点 发布 数据 注册 数据 提供 公众 发布 数据 数据 存储 发送 请求 检索 数据 在实践中 两种 类型 数据 查询 首先 两步 其中 步骤 查询 搜索 数据 步骤 访问 数据 例如 使用 服务 通常 首先 调用 特征 服务 获取 特征描述  ...
